# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Data visualiization using Matplotlib******

# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data

# %%
austres=data('austres')
austres
# Out:
#        time  austres
# 1   1971.25  13067.3
# 2   1971.50  13130.5
# 3   1971.75  13198.4
# 4   1972.00  13254.2
# 5   1972.25  13303.7
# 6   1972.50  13353.9
# 7   1972.75  13409.3
# 8   1973.00  13459.2
# 9   1973.25  13504.5
# 10  1973.50  13552.6
# 11  1973.75  13614.3
# 12  1974.00  13669.5
# 13  1974.25  13722.6
# 14  1974.50  13772.1
# 15  1974.75  13832.0
# 16  1975.00  13862.6
# 17  1975.25  13893.0
# 18  1975.50  13926.8
# 19  1975.75  13968.9
# 20  1976.00  14004.7
# 21  1976.25  14033.1
# 22  1976.50  14066.0
# 23  1976.75  14110.1
# 24  1977.00  14155.6
# 25  1977.25  14192.2
# 26  1977.50  14231.7
# 27  1977.75  14281.5
# 28  1978.00  14330.3
# 29  1978.25  14359.3
# 30  1978.50  14396.6
# 31  1978.75  14430.8
# 32  1979.00  14478.4
# 33  1979.25  14515.7
# 34  1979.50  14554.9
# 35  1979.75  14602.5
# 36  1980.00  14646.4
# 37  1980.25  14695.4
# 38  1980.50  14746.6
# 39  1980.75  14807.4
# 40  1981.00  14874.4
# 41  1981.25  14923.3
# 42  1981.50  14988.7
# ...

# %%
austres.head()
# Out:
#       time  austres
# 1  1971.25  13067.3
# 2  1971.50  13130.5
# 3  1971.75  13198.4
# 4  1972.00  13254.2
# 5  1972.25  13303.7

# %%
#Line plot ( u need to mention the label while using the plt.legend() method )

plt.figure(figsize=(10,4))
plt.plot(austres['time'],austres['austres'],label='Population')
plt.plot(austres['time'],austres['austres']+1000,label='Population+1000')
plt.xlabel('time')
plt.ylabel('austres')
plt.title('title vs austres')
plt.legend()
plt.grid(alpha=1,ls=':')
plt.show()

# %%
#bar plot
plt.bar(x=bedroom_count.index,
       height=bedrooms_counts,);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10204\467656289.py in <module>
#       1 #bar plot
# ----> 2 plt.bar(x=bedroom_count.index,
#       3        height=bedrooms_counts,);
#
# NameError: name 'bedroom_count' is not defined

# %%
#histogram
plt.hist(austres['austres'],bins=20,
        histtype='step');
plt.grid(alpha=0.2)

# %%
#scatter plot

plt.scatter(x=austres['time'],
           y=austres['austres'])
plt.xlabel('time')
plt.ylabel('austres')
plt.title('time vs austres')
plt.grid(alpha=0.1)
plt.show()

# %%
p=austres['austres'].value_counts()
plt.pie(p)
plt.title('time vs austres')
# Out:
# Text(0.5, 1.0, 'time vs austres')

# %%
plt.subplot()
# Out:
# <AxesSubplot:>
